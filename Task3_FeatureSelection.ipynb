# %% [markdown]
# <h1 style="color:rgb(0,120,170)">Task 3 <h1>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /home/ricarda/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
labels_df = pd.read_csv('task_3_training_5bdf9a9ed30b9a66_749fa46_generic.csv',header=0)

# %%
df_head = labels_df.columns.values

# %%
labels_df['quadrant'].value_counts()
# Out:
# 4.0    729
# 3.0    635
# 1.0    494
# 2.0    424
# Name: quadrant, dtype: int64

# %%
#print(df_head[3:172])
feature_df = labels_df.iloc[:,3:172]
feature_df
# Out:
#       essentia_dissonance_mean  essentia_dissonance_stdev  \
# 0                     0.192237                   0.059404
# 1                     0.143425                   0.064204
# 2                     0.146967                   0.056205
# 3                     0.158810                   0.059129
# 4                     0.168547                   0.049648
# ...                        ...                        ...
# 2277                  0.202177                   0.050760
# 2278                  0.174454                   0.063426
# 2279                  0.161152                   0.074724
# 2280                  0.192846                   0.056795
# 2281                  0.208580                   0.087355
#
#       essentia_dynamic_complexity  essentia_loudness  essentia_onset_rate  \
# 0                        2.040252         16079768.0             0.800000
# 1                        3.138845         35489248.0             2.600000
# ...

# %%
correlation = feature_df.corr()

# %%
correlation
# Out:
#                              essentia_dissonance_mean  \
# essentia_dissonance_mean                     1.000000
# essentia_dissonance_stdev                    0.116425
# essentia_dynamic_complexity                 -0.220164
# essentia_loudness                            0.541317
# essentia_onset_rate                          0.037410
# ...                                               ...
# mirtoolbox_roughness_mean                    0.635549
# mirtoolbox_roughness_std                     0.220241
# mirtoolbox_roughness_pct_10                  0.617400
# mirtoolbox_roughness_pct_50                  0.641805
# mirtoolbox_roughness_pct_90                  0.585331
#
#                              essentia_dissonance_stdev  \
# essentia_dissonance_mean                      0.116425
# essentia_dissonance_stdev                     1.000000
# essentia_dynamic_complexity                   0.218579
# essentia_loudness                            -0.116427
# ...

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top Absolute Correlations")
print(get_top_abs_correlations(correlation, 50))
# Out:
# Top Absolute Correlations
# librosa_mfcc_mean_0          librosa_mfcc_pct_50_0          0.999963
# librosa_mfcc_mean_2          librosa_mfcc_pct_50_2          0.999928
# librosa_mfcc_mean_6          librosa_mfcc_pct_50_6          0.999861
# mirtoolbox_roughness_mean    mirtoolbox_roughness_pct_50    0.999811
# librosa_mfcc_mean_7          librosa_mfcc_pct_50_7          0.999763
# librosa_mfcc_mean_3          librosa_mfcc_pct_50_3          0.999726
# librosa_mfcc_mean_5          librosa_mfcc_pct_50_5          0.999591
# librosa_mfcc_mean_8          librosa_mfcc_pct_50_8          0.999538
# mirtoolbox_dynamics_mean     mirtoolbox_dynamics_pct_50     0.999521
# librosa_mfcc_mean_1          librosa_mfcc_pct_50_1          0.999302
# librosa_mfcc_mean_10         librosa_mfcc_pct_50_10         0.998873
# librosa_mfcc_mean_9          librosa_mfcc_pct_50_9          0.998688
# mirtoolbox_dynamics_pct_50   mirtoolbox_dynamics_pct_90     0.998626
# ...

# %%
def get_bottom_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=True)
    return au_corr[0:n]

print("Bottom Absolute Correlations")
print(get_bottom_abs_correlations(correlation, 50))
# Out:
# Bottom Absolute Correlations
# librosa_mfcc_pct_90_6              mirtoolbox_keyclarity                 0.000069
# librosa_chroma_pct_10_2            librosa_mfcc_pct_90_9                 0.000102
# librosa_mfcc_mean_4                librosa_mfcc_mean_11                  0.000146
# essentia_dissonance_stdev          librosa_mfcc_pct_50_9                 0.000373
# librosa_chroma_mean_4              librosa_mfcc_std_1                    0.000420
# librosa_chroma_mean_0              mirtoolbox_mode                       0.000455
# librosa_chroma_pct_90_1            librosa_mfcc_pct_50_11                0.000471
# librosa_mfcc_pct_50_4              mirtoolbox_roughness_pct_90           0.000492
# midlevel_features_minorness        mirtoolbox_keyclarity                 0.000527
# librosa_chroma_pct_10_8            librosa_mfcc_mean_2                   0.000640
# librosa_chroma_pct_10_3            librosa_chroma_std_4                  0.000784
# ...

# %%
def get_all_abs_correlations(df):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=True)
    return au_corr
ordered_corr = get_all_abs_correlations(correlation)

# %%
print(ordered_corr[:60])
# Out:
# librosa_mfcc_pct_90_6               mirtoolbox_keyclarity                 0.000069
# librosa_chroma_pct_10_2             librosa_mfcc_pct_90_9                 0.000102
# librosa_mfcc_mean_4                 librosa_mfcc_mean_11                  0.000146
# essentia_dissonance_stdev           librosa_mfcc_pct_50_9                 0.000373
# librosa_chroma_mean_4               librosa_mfcc_std_1                    0.000420
# librosa_chroma_mean_0               mirtoolbox_mode                       0.000455
# librosa_chroma_pct_90_1             librosa_mfcc_pct_50_11                0.000471
# librosa_mfcc_pct_50_4               mirtoolbox_roughness_pct_90           0.000492
# midlevel_features_minorness         mirtoolbox_keyclarity                 0.000527
# librosa_chroma_pct_10_8             librosa_mfcc_mean_2                   0.000640
# librosa_chroma_pct_10_3             librosa_chroma_std_4                  0.000784
# ...

# %%
print(ordered_corr[60:120])
# Out:
# librosa_chroma_mean_8              librosa_mfcc_mean_11                   0.002658
# librosa_mfcc_pct_90_2              librosa_mfcc_pct_50_9                  0.002670
# librosa_chroma_pct_10_9            mirtoolbox_dynamics_mean               0.002704
# librosa_chroma_pct_90_0            mirtoolbox_novelty_pct_90              0.002716
# librosa_chroma_pct_10_3            midlevel_features_tonal_stability      0.002742
# librosa_chroma_pct_90_8            librosa_mfcc_pct_90_3                  0.002785
# librosa_mfcc_std_1                 librosa_mfcc_std_8                     0.002787
# librosa_chroma_std_0               mirtoolbox_roughness_mean              0.002799
# librosa_mfcc_std_7                 mirtoolbox_novelty_pct_50              0.002847
# librosa_chroma_pct_90_5            mirtoolbox_crescendo                   0.002860
# librosa_chroma_pct_90_4            mirtoolbox_hcdf_pct_10                 0.002892
# ...

# %%
print(ordered_corr[120:180])
# Out:
# essentia_loudness                 librosa_mfcc_std_6                   0.004603
# librosa_bpm                       librosa_mfcc_pct_90_9                0.004631
# librosa_chroma_std_1              midlevel_features_dissonance         0.004654
# essentia_spectral_centroid_mean   mirtoolbox_mode                      0.004716
# librosa_mfcc_pct_10_3             mirtoolbox_novelty_pct_50            0.004724
# librosa_chroma_std_1              mirtoolbox_dynamics_mean             0.004787
# librosa_chroma_pct_50_11          mirtoolbox_novelty_pct_50            0.004817
# librosa_chroma_pct_10_1           librosa_mfcc_pct_90_10               0.004822
# essentia_dissonance_stdev         librosa_mfcc_pct_50_1                0.004863
# librosa_chroma_pct_10_8           librosa_mfcc_pct_90_1                0.004881
# essentia_pitch_salience_mean      librosa_chroma_std_1                 0.004894
# librosa_chroma_pct_90_1           librosa_chroma_pct_90_8              0.005011
# ...

# %%
def get_all_abs_correlations_desc(df):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr
ordered_corr_desc = get_all_abs_correlations_desc(correlation)

# %%
print(ordered_corr_desc[:60])
# Out:
# librosa_mfcc_mean_0           librosa_mfcc_pct_50_0                0.999963
# librosa_mfcc_mean_2           librosa_mfcc_pct_50_2                0.999928
# librosa_mfcc_mean_6           librosa_mfcc_pct_50_6                0.999861
# mirtoolbox_roughness_mean     mirtoolbox_roughness_pct_50          0.999811
# librosa_mfcc_mean_7           librosa_mfcc_pct_50_7                0.999763
# librosa_mfcc_mean_3           librosa_mfcc_pct_50_3                0.999726
# librosa_mfcc_mean_5           librosa_mfcc_pct_50_5                0.999591
# librosa_mfcc_mean_8           librosa_mfcc_pct_50_8                0.999538
# mirtoolbox_dynamics_mean      mirtoolbox_dynamics_pct_50           0.999521
# librosa_mfcc_mean_1           librosa_mfcc_pct_50_1                0.999302
# librosa_mfcc_mean_10          librosa_mfcc_pct_50_10               0.998873
# librosa_mfcc_mean_9           librosa_mfcc_pct_50_9                0.998688
# ...

# %%
print(ordered_corr_desc[60:120])
# Out:
# librosa_mfcc_mean_0        librosa_mfcc_mean_2                  0.983855
# librosa_mfcc_pct_50_0      librosa_mfcc_pct_50_2                0.983777
# librosa_mfcc_mean_0        librosa_mfcc_pct_50_2                0.983708
# librosa_mfcc_pct_10_0      mirtoolbox_dynamics_pct_10           0.983600
# librosa_mfcc_pct_10_3      librosa_mfcc_pct_50_3                0.983571
# librosa_mfcc_mean_2        mirtoolbox_dynamics_pct_50           0.982514
#                            mirtoolbox_dynamics_mean             0.982394
# librosa_mfcc_pct_10_0      mirtoolbox_dynamics_pct_50           0.982337
# librosa_mfcc_pct_10_2      mirtoolbox_dynamics_pct_90           0.982174
# librosa_mfcc_pct_50_2      mirtoolbox_dynamics_pct_50           0.982022
# librosa_mfcc_pct_10_0      mirtoolbox_dynamics_mean             0.982008
# librosa_mfcc_pct_50_2      mirtoolbox_dynamics_mean             0.981947
# librosa_mfcc_std_9         librosa_mfcc_std_10                  0.981821
# ...

# %%
print(ordered_corr_desc[120:180])
# Out:
# essentia_loudness              librosa_mfcc_pct_10_0          0.964016
# librosa_mfcc_pct_90_2          mirtoolbox_dynamics_pct_90     0.963438
# essentia_strong_peak_mean      mirtoolbox_dynamics_pct_10     0.963436
# essentia_dynamic_complexity    librosa_mfcc_std_1             0.963425
# essentia_strong_peak_stdev     mirtoolbox_dynamics_pct_90     0.962884
# librosa_mfcc_pct_10_6          librosa_mfcc_pct_50_6          0.962204
# librosa_mfcc_mean_4            librosa_mfcc_pct_90_4          0.961925
# librosa_mfcc_pct_10_4          librosa_mfcc_pct_50_4          0.961408
# mirtoolbox_novelty_mean        mirtoolbox_novelty_pct_50      0.961313
# librosa_mfcc_pct_10_5          librosa_mfcc_pct_50_5          0.961134
# essentia_pitch_salience_stdev  mirtoolbox_roughness_pct_10    0.961004
# essentia_strong_peak_mean      librosa_mfcc_mean_0            0.960942
#                                librosa_mfcc_pct_90_0          0.959678
# ...

# %% [markdown]
# Combination of features with high correlation:

# %%
librosa_mfcc_mean_0:           librosa_mfcc_pct_50_0,librosa_mfcc_pct_90_0,librosa_mfcc_pct_10_0,
                               mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,mirtoolbox_dynamics_pct_10,
                               mirtoolbox_dynamics_pct_90,librosa_mfcc_mean_2,librosa_mfcc_pct_50_2,
                               librosa_mfcc_pct_90_2,librosa_mfcc_pct_10_2
librosa_mfcc_mean_1:           librosa_mfcc_pct_50_1,librosa_mfcc_pct_10_1
librosa_mfcc_mean_2:           librosa_mfcc_pct_50_2,librosa_mfcc_pct_90_2,librosa_mfcc_pct_10_2,
                               mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,mirtoolbox_dynamics_pct_10,
                               mirtoolbox_dynamics_pct_90
librosa_mfcc_mean_3:           librosa_mfcc_pct_50_3,librosa_mfcc_pct_10_3,librosa_mfcc_pct_90_3
librosa_mfcc_mean_4:           librosa_mfcc_pct_50_4,librosa_mfcc_pct_10_4,librosa_mfcc_pct_90_4
librosa_mfcc_mean_5:           librosa_mfcc_pct_50_5,librosa_mfcc_pct_10_5
librosa_mfcc_mean_6:           librosa_mfcc_pct_50_6,librosa_mfcc_pct_10_6
librosa_mfcc_mean_7:           librosa_mfcc_pct_50_7
librosa_mfcc_mean_8:           librosa_mfcc_pct_50_8,librosa_mfcc_pct_10_8
librosa_mfcc_mean_9:           librosa_mfcc_pct_50_9
librosa_mfcc_mean_10:          librosa_mfcc_pct_50_10
librosa_mfcc_mean_11:          librosa_mfcc_pct_50_11

librosa_mfcc_pct_10_0:         librosa_mfcc_pct_50_0,librosa_mfcc_pct_90_0,librosa_mfcc_pct_90_2,
                               mirtoolbox_dynamics_pct_10,mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,
                               librosa_mfcc_pct_50_2,librosa_mfcc_mean_2,mirtoolbox_dynamics_pct_90,
                               librosa_mfcc_pct_10_2
librosa_mfcc_pct_10_1:         librosa_mfcc_pct_50_1
librosa_mfcc_pct_10_2:         librosa_mfcc_pct_50_2,mirtoolbox_dynamics_pct_90,mirtoolbox_dynamics_mean,
                               mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_pct_10,librosa_mfcc_pct_90_2
librosa_mfcc_pct_10_3:         librosa_mfcc_pct_50_3
librosa_mfcc_pct_10_4:         librosa_mfcc_pct_50_4
librosa_mfcc_pct_10_5:         librosa_mfcc_pct_50_5
librosa_mfcc_pct_10_6:         librosa_mfcc_pct_50_6
librosa_mfcc_pct_10_8:         librosa_mfcc_pct_50_8
librosa_mfcc_pct_50_0:         librosa_mfcc_pct_90_0,mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,
                               mirtoolbox_dynamics_pct_10,mirtoolbox_dynamics_pct_90,librosa_mfcc_mean_2,
                               librosa_mfcc_pct_50_2,librosa_mfcc_pct_90_2,librosa_mfcc_pct_10_2
librosa_mfcc_pct_50_2:         librosa_mfcc_pct_90_2,mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,
                               mirtoolbox_dynamics_pct_10,mirtoolbox_dynamics_pct_90
librosa_mfcc_pct_50_3:         librosa_mfcc_pct_90_3
librosa_mfcc_pct_50_4:         librosa_mfcc_pct_90_4
librosa_mfcc_pct_50_5:         librosa_mfcc_pct_90_5
librosa_mfcc_pct_90_0:         mirtoolbox_dynamics_pct_90,mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,
                               mirtoolbox_dynamics_pct_10,librosa_mfcc_mean_2,librosa_mfcc_pct_50_2,
                               librosa_mfcc_pct_10_2,librosa_mfcc_pct_90_2
librosa_mfcc_pct_90_2:         mirtoolbox_dynamics_pct_10,mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,
                               mirtoolbox_dynamics_pct_90

librosa_mfcc_std_6:            librosa_mfcc_std_7
librosa_mfcc_std_7:            librosa_mfcc_std_8
librosa_mfcc_std_8             librosa_mfcc_std_9,librosa_mfcc_std_10
librosa_mfcc_std_9:            librosa_mfcc_std_10
librosa_mfcc_std_10:           librosa_mfcc_std_11

librosa_chroma_mean_0:         librosa_chroma_pct_50_0
librosa_chroma_mean_1:         librosa_chroma_pct_50_1
librosa_chroma_mean_2:         librosa_chroma_pct_50_2
librosa_chroma_mean_3:         librosa_chroma_pct_50_3
librosa_chroma_mean_4:         librosa_chroma_pct_50_4
librosa_chroma_mean_5:         librosa_chroma_pct_50_5
librosa_chroma_mean_6:         librosa_chroma_pct_50_6
librosa_chroma_mean_7:         librosa_chroma_pct_50_7
librosa_chroma_mean_8:         librosa_chroma_pct_50_8                    
librosa_chroma_mean_9:         librosa_chroma_pct_50_9
librosa_chroma_mean_10:        librosa_chroma_pct_50_10
librosa_chroma_mean_11:        librosa_chroma_pct_50_11
librosa_chroma_pct_10_2:       librosa_chroma_pct_10_3

mirtoolbox_roughness_mean:     mirtoolbox_roughness_pct_50,mirtoolbox_roughness_pct_90,mirtoolbox_roughness_pct_10
mirtoolbox_roughness_pct_10:   mirtoolbox_roughness_pct_50
mirtoolbox_roughness_pct_50:   mirtoolbox_roughness_pct_90
mirtoolbox_dynamics_mean:      mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_pct_10,mirtoolbox_dynamics_pct_90
mirtoolbox_dynamics_pct_10:    mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_pct_90  
mirtoolbox_dynamics_pct_50:    mirtoolbox_dynamics_pct_90                              
mirtoolbox_novelty_mean:       mirtoolbox_novelty_pct_90,mirtoolbox_novelty_pct_50,mirtoolbox_novelty_std
mirtoolbox_novelty_std:        mirtoolbox_novelty_pct_90
mirtoolbox_hcdf_mean:          mirtoolbox_hcdf_pct_50

essentia_strong_peak_mean:     essentia_strong_peak_stdev,mirtoolbox_dynamics_pct_90,mirtoolbox_dynamics_pct_50,
                               mirtoolbox_dynamics_mean,mirtoolbox_dynamics_pct_10,librosa_mfcc_mean_0,
                               librosa_mfcc_pct_90_0,librosa_mfcc_pct_50_0,librosa_mfcc_pct_10_0
essentia_strong_peak_stdev:    mirtoolbox_dynamics_pct_90,mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,
                               librosa_mfcc_pct_90_0,mirtoolbox_dynamics_pct_10,librosa_mfcc_mean_0
essentia_loudness:             librosa_mfcc_mean_0,librosa_mfcc_pct_90_0,librosa_mfcc_pct_50_0,
                               librosa_mfcc_pct_10_0,mirtoolbox_dynamics_pct_50,mirtoolbox_dynamics_mean,
                               mirtoolbox_dynamics_pct_10
essentia_dynamic_complexity:   librosa_mfcc_std_1
essentia_pitch_salience_stdev: mirtoolbox_roughness_pct_10

midlevel_features_dissonance:  midlevel_features_tonal_stability
midlevel_features_melody:      midlevel_features_tonal_stability,midlevel_features_dissonance
# Out:
#   File "<ipython-input-18-75cf49e8045c>", line 1
#     librosa_mfcc_mean_0:           librosa_mfcc_pct_50_0,librosa_mfcc_pct_90_0,librosa_mfcc_pct_10_0,
#                                                         ^
# SyntaxError: invalid syntax

# %% [markdown]
# Features to be excluded:

# %%
midlevel_features_tonal_stability
midlevel_features_dissonance
essentia_strong_peak_stdev
librosa_chroma_pct_10_3
librosa_chroma_pct_50_0
librosa_chroma_pct_50_1
librosa_chroma_pct_50_2
librosa_chroma_pct_50_3
librosa_chroma_pct_50_4
librosa_chroma_pct_50_5
librosa_chroma_pct_50_6
librosa_chroma_pct_50_7
librosa_chroma_pct_50_8                    
librosa_chroma_pct_50_9
librosa_chroma_pct_50_10
librosa_chroma_pct_50_11
mirtoolbox_hcdf_pct_50
mirtoolbox_novelty_pct_50
mirtoolbox_novelty_std
mirtoolbox_novelty_pct_90
mirtoolbox_roughness_pct_10
mirtoolbox_roughness_pct_50
mirtoolbox_roughness_pct_90
mirtoolbox_dynamics_mean
mirtoolbox_dynamics_pct_10
mirtoolbox_dynamics_pct_50
mirtoolbox_dynamics_pct_90
librosa_mfcc_std_1
librosa_mfcc_std_7
librosa_mfcc_std_8
librosa_mfcc_std_9
librosa_mfcc_std_10
librosa_mfcc_std_11
librosa_mfcc_pct_50_8
librosa_mfcc_pct_50_9
librosa_mfcc_pct_50_10
librosa_mfcc_pct_50_11
librosa_mfcc_pct_50_6
librosa_mfcc_pct_50_7
librosa_mfcc_pct_50_1
librosa_mfcc_pct_90_3
librosa_mfcc_pct_90_4
librosa_mfcc_pct_90_5
librosa_mfcc_pct_10_8
librosa_mfcc_pct_10_6
librosa_mfcc_pct_50_5
librosa_mfcc_pct_10_5
librosa_mfcc_pct_50_4
librosa_mfcc_pct_10_4
librosa_mfcc_pct_10_3
librosa_mfcc_pct_50_3
librosa_mfcc_pct_10_1
librosa_mfcc_pct_10_2
librosa_mfcc_pct_50_2
librosa_mfcc_pct_90_2
librosa_mfcc_pct_10_0
librosa_mfcc_pct_50_0
librosa_mfcc_pct_90_0
librosa_mfcc_mean_0
librosa_mfcc_mean_2
